# %% [raw]
# ---
# description: An experiment with Weaviate, a vector database that allows semantic search
#   and content generation, using CSV data, CSVW schema, text2vec-transformers module
#   and OpenAI inference API.
# output-file: index.html
# title: weaviate-csv-experiment
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install weaviate_csv_experiment
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
